# %%
# Start handshake/heartbeat/control stream
from drone import start_drone
import time

drone = start_drone(verbose=True)

# %%
# Example: small throttle bump
drone.takeoff()
drone.set_axes(x=0x70)
time.sleep(1.0)
drone.set_axes(z=0x90)
time.sleep(1.0)
drone.neutral()
time.sleep(2.0)
drone.set_axes(z=0x70)
time.sleep(1.0)
drone.land()

# %%
drone.estop()
# Out:
# [RX] udp src=40000 len=106 head=63630169006300524144434c4f465056
# [RX] udp src=40000 len=106 head=636301e2016300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630110006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630111006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630101006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630103006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630105006300524144434c4f465056
# [RX] udp src=40000 len=106 head=636301c6006300524144434c4f465056
# [RX] udp src=40000 len=106 head=636301d8006300524144434c4f465056
# [RX] udp src=40000 len=106 head=636301fb006300524144434c4f465056
# [RX] udp src=40000 len=106 head=636301fc006300524144434c4f465056
# [RX] udp src=40000 len=106 head=636301fe006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630106006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630107006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630101006300524144434c4f465056
# [RX] udp src=40000 len=106 head=636301b3006300524144434c4f465056
# [RX] udp src=40000 len=106 head=636301b5006300524144434c4f465056
# [RX] udp src=40000 len=106 head=636301b6006300524144434c4f465056
# [RX] udp src=40000 len=106 head=636301b8006300524144434c4f465056
# [RX] udp src=40000 len=106 head=636301b9006300524144434c4f465056
# [RX] udp src=40000 len=106 head=636301ca006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630116016300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630118016300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630119016300524144434c4f465056
# [RX] udp src=40000 len=106 head=6363011b016300524144434c4f465056
# [RX] udp src=40000 len=106 head=6363011d016300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630181016300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630182016300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630153026300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630154026300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630155026300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630156026300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630157026300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630159026300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630178026300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630101006300524144434c4f465056

# %%
# Video (widget)
# If this errors, run: cd controller && uv sync
drone.enable_video()
drone.show_video_widget()
